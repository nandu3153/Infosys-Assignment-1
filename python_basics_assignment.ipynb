# %% [markdown]
# # ***Python Basics Assignment***
# **Submitted by: M. Narayan Naidu**
#
# **Date: 4st December 2025**
#
# This assignment demonstrates class and Object-Oriented Programming concepts in Python:
#
# 1. class and object
# 2. Encapsulation
# 3. Inheritance
# 4. Polymorphism
# 5. Extraction
#
# The aim is to show basic understanding of how OOP structures are created and used in Python.

# %% [markdown]
# # ***1. CLASS AND OBJECT***

# %% [markdown]
# ***Example***

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

# Class: Car, Object: my_car
my_car = Car("Toyota")
print(f"My {my_car.brand}")

# %% [markdown]
# # ***2. ENCAPSULATION***

# %% [markdown]
# ***Example 1***

# %%
class AudioFile:
    def __init__(self, name, duration):
        self.__name = name          # private
        self.__duration = duration  # private

    def get_name(self):
        return self.__name

    def get_duration(self):
        return self.__duration

# %% [markdown]
# ***Example 2***

# %%
class Recorder:
    def __init__(self):
        self.__is_recording = False

    def start(self):
        self.__is_recording = True

    def stop(self):
        self.__is_recording = False

    def is_recording(self):
        return self.__is_recording

# %% [markdown]
# ***Example 3***

# %%
class VolumeControl:
    def __init__(self):
        self.__level = 50  

    def set_volume(self, value):
        self.__level = value

    def get_volume(self):
        return self.__level

# %% [markdown]
# #***3. Inheritance***

# %%
class Animal:
    def speak(self):
        return "Some sound"

class Dog(Animal):
    pass   

class Cat(Animal):
    pass   

class Cow(Animal):
    pass  

print(Dog().speak())
print(Cat().speak())
print(Cow().speak())

# %% [markdown]
# #***4. Polymorphism***

# %%
class Shape:
    def area(self):
        return 0
class Square(Shape):
    def area(self):
        return "Area = side × side"
class Rectangle(Shape):
    def area(self):
        return "Area = length × width"
class Circle(Shape):
    def area(self):
        return "Area = π × r²"

shapes = [Square(), Rectangle(), Circle()]
for s in shapes:
    print(s.area())

# %% [markdown]
# #***5. Extraction***

# %%
class Data:
    def extract(self, data):
        return f"Extracting data: {data}"
class Name:
    def extract(self, student_name):
        return f"Extracted name: {student_name}"
class Price:
    def extract(self, price):
        return f"Extracted price: ₹{price}"

print(Name().extract("Narayan naidu"))
